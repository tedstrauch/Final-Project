# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Happy2015 = pd.read_csv('C:/Users/singe/Downloads/2015.csv')
Happy2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
HAPPY2015 = Happy2015[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)']]
HAPPY2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629

# %%
child_mortality = pd.read_csv('C:/Users/singe/Downloads/U5MR_deaths.csv')
child_mortality.head()
# Out:
#   ISO Code  CountryName Uncertainty bounds* 1955.5 1956.5 1957.5 1958.5  \
# 0      AFG  Afghanistan               Lower    NaN    NaN    NaN    NaN
# 1      AFG  Afghanistan              Median    NaN    NaN    NaN    NaN
# 2      AFG  Afghanistan               Upper    NaN    NaN    NaN    NaN
# 3      ALB      Albania               Lower    NaN    NaN    NaN    NaN
# 4      ALB      Albania              Median    NaN    NaN    NaN    NaN
#
#   1959.5 1960.5 1961.5  ...   2009.5   2010.5   2011.5   2012.5   2013.5  \
# 0    NaN    NaN    NaN  ...   97,607   93,455   89,155   84,664   80,132
# 1    NaN    NaN    NaN  ...  105,746  101,882   97,906   93,956   90,103
# 2    NaN    NaN    NaN  ...  114,731  111,090  107,471  104,015  100,789
# 3    NaN    NaN    NaN  ...      479      446      416      390      366
# 4    NaN    NaN    NaN  ...      517      474      438      406      380
#
#    2014.5  2015.5  2016.5  2017.5 2017.5.1
# 0  75,600  71,242  67,382  63,692   60,178
# ...

# %%
child_mortality.rename(columns={'CountryName' : 'Country', 'Uncertainty bounds*' : 'Uncertainty bounds', '2015.5' : 'Child Mortality 2015.5'}, inplace=True)
child_mortality.head()
# Out:
#   ISO Code      Country Uncertainty bounds 1955.5 1956.5 1957.5 1958.5 1959.5  \
# 0      AFG  Afghanistan              Lower    NaN    NaN    NaN    NaN    NaN
# 1      AFG  Afghanistan             Median    NaN    NaN    NaN    NaN    NaN
# 2      AFG  Afghanistan              Upper    NaN    NaN    NaN    NaN    NaN
# 3      ALB      Albania              Lower    NaN    NaN    NaN    NaN    NaN
# 4      ALB      Albania             Median    NaN    NaN    NaN    NaN    NaN
#
#   1960.5 1961.5  ...   2009.5   2010.5   2011.5   2012.5   2013.5  2014.5  \
# 0    NaN    NaN  ...   97,607   93,455   89,155   84,664   80,132  75,600
# 1    NaN    NaN  ...  105,746  101,882   97,906   93,956   90,103  86,378
# 2    NaN    NaN  ...  114,731  111,090  107,471  104,015  100,789  97,847
# 3    NaN    NaN  ...      479      446      416      390      366     345
# 4    NaN    NaN  ...      517      474      438      406      380     358
#
#   Child Mortality 2015.5  2016.5  2017.5 2017.5.1
# ...

# %%
CM = child_mortality[[ 'Country', 'Uncertainty bounds', 'Child Mortality 2015.5']]
CM.head()
# Out:
#        Country Uncertainty bounds Child Mortality 2015.5
# 0  Afghanistan              Lower                 71,242
# 1  Afghanistan             Median                 82,918
# 2  Afghanistan              Upper                 95,244
# 3      Albania              Lower                    327
# 4      Albania             Median                    340

# %%
CM2 = CM[child_mortality['Uncertainty bounds']=="Median"]
CM2.head()
# Out:
#         Country Uncertainty bounds Child Mortality 2015.5
# 1   Afghanistan             Median                 82,918
# 4       Albania             Median                    340
# 7       Algeria             Median                 24,791
# 10      Andorra             Median                      2
# 13       Angola             Median                100,834

# %%
Happy2 = pd.merge(HAPPY2015, CM2)

# %%
Happy2.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#   Uncertainty bounds Child Mortality 2015.5
# 0             Median                    367
# 1             Median                     10
# 2             Median                    249
# 3             Median                    161
# 4             Median                  2,033

# %%
Happy3 = Happy2.drop(['Uncertainty bounds'], axis=1)
Happy3.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#   Child Mortality 2015.5
# 0                    367
# 1                     10
# 2                    249
# 3                    161
# 4                  2,033

# %%
Happy3.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row0_col2 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row1_col2 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_51dc8bf6_0e7b_11eb_a93c_4cebbd07d4d8row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
Happy3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 0 to 135
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   136 non-null    object
#  1   Happiness Rank            136 non-null    int64
#  2   Happiness Score           136 non-null    float64
#  3   Economy (GDP per Capita)  136 non-null    float64
#  4   Child Mortality 2015.5    136 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 6.4+ KB

# %%
Happy3 = Happy3.str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7214cdb7f8b9> in <module>
# ----> 1 Happy3 = Happy3.str.replace(',', '').astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
Happy4 = Happy2.drop(['Uncertainty bounds', 'Country'], axis=1)
Happy4.head()

# %%
Happy4.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
